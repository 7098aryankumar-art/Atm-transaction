# %%
balance = 5000
pin = 1234
user_pin = int (input("Enter your pin:"))

if user_pin == pin :
    print("your balance is:", balance)
    amount = int (input ("enter amount to withdrawl :"))
    balance -= amount 
    print ("congrats amount recived", "new balance is" , balance)
else :
    print ("pin Incorrect")
# Out:
# Enter your pin: 1234
# your balance is: 5000
# enter amount to withdrawl : 2000
# congrats amount recived new balance is 3000
